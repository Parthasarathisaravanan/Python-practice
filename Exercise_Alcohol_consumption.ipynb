# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarizes as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
res=drinks.groupby(['continent']).sum()
res.sum(axis=1).head(1)
# Out:
# continent
# AF    5145.4
# dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
res['wine_servings']
# Out:
# continent
# AF     862
# AS     399
# EU    6400
# OC     570
# SA     749
# Name: wine_servings, dtype: int64

# %% [markdown]
# ### Step 6. Print the mean alcoohol consumption per continent for every column

# %%
#drinks.merge(res,on='continent')
#pd.merge(drinks, res, on='continent')
res['mean_alcohol'] = res.mean(axis=1)
#res=res.drop(['beer_servings', 'spirit_servings','wine_servings','total_litres_of_pure_alcohol'], axis = 1)
res
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol  mean_alcohol
# continent
# AF                                159.4      1286.350
# AS                                 95.5      1200.375
# EU                                387.8      5368.200
# OC                                 54.1       748.525
# SA                                 75.7      1075.675

# %%
#res=res.drop(['beer_servings', 'spirit_servings','wine_servings','total_litres_of_pure_alcohol'], axis = 1)
ans=pd.merge(drinks,res,on='continent')
ans
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Bahrain             42               63              7
# 2         Bangladesh              0                0              0
# 3             Bhutan             23                0              0
# 4             Brunei             31                2              1
# ..               ...            ...              ...            ...
# 165            Samoa            105               18             24
# 166  Solomon Islands             56               11              1
# 167            Tonga             36               21              5
# 168           Tuvalu              6               41              9
# 169          Vanuatu             21               18             11
#
#      total_litres_of_pure_alcohol continent  mean_alcohol
# 0                             0.0        AS      1200.375
# ...

# %% [markdown]
# ### Step 7. Print the median alcoohol consumption per continent for every column

# %%
res1=drinks.groupby(['continent']).sum()
res1.sum(axis=1).head(1)
res['median_alcohol']=res1.median(axis=1)
res
# Out:
#            mean_alcohol  median_alcohol
# continent
# AF             1286.350           864.0
# AS             1200.375          1014.5
# EU             5368.200          6182.5
# OC              748.525           752.5
# SA             1075.675          1063.0

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol
# continent
# AF                                159.4
# AS                                 95.5
# EU                                387.8
# OC                                 54.1
# SA                                 75.7
